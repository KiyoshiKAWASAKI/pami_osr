# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import sys

# %% [markdown]
# # Plot the RT for running 5 sample n times

# %%
untrained_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/five_sample_rts/untrained/"
original_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/five_sample_rts/original/"
pp_mul_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/five_sample_rts/pp_mul/"
pp_add_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/five_sample_rts/pp_add/"

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(511)
# plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
# plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
# plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
# plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
# plt.xlim(0, 0.05)

for i in range(1000):
    one_train_npy = np.load(untrained_dir + "rt_itr_" + str(i) + ".npy")
    ax1.hist(one_train_npy[:, 0])
    ax2.hist(one_train_npy[:, 1])
    ax3.hist(one_train_npy[:, 2])
    ax4.hist(one_train_npy[:, 3])
    ax5.hist(one_train_npy[:, 4])

# %%
plt.figure(figsize=(12, 12))

ax1 = plt.subplot(511)
# plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
# plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
# plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
# plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
# plt.xlim(0, 0.05)

for i in range(1000):
    one_train_npy = np.load(original_dir + "rt_itr_" + str(i) + ".npy")
    ax1.hist(one_train_npy[:, 0])
    ax2.hist(one_train_npy[:, 1])
    ax3.hist(one_train_npy[:, 2])
    ax4.hist(one_train_npy[:, 3])
    ax5.hist(one_train_npy[:, 4])

# %%
plt.figure(figsize=(12, 12))

ax1 = plt.subplot(511)
# plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
# plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
# plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
# plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
# plt.xlim(0, 0.05)

for i in range(1000):
    one_train_npy = np.load(pp_mul_dir + "rt_itr_" + str(i) + ".npy")
    ax1.hist(one_train_npy[:, 0])
    ax2.hist(one_train_npy[:, 1])
    ax3.hist(one_train_npy[:, 2])
    ax4.hist(one_train_npy[:, 3])
    ax5.hist(one_train_npy[:, 4])

# %%
plt.figure(figsize=(12, 12))

ax1 = plt.subplot(511)
# plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
# plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
# plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
# plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
# plt.xlim(0, 0.05)

for i in range(1000):
    one_train_npy = np.load(pp_add_dir + "rt_itr_" + str(i) + ".npy")
    ax1.hist(one_train_npy[:, 0])
    ax2.hist(one_train_npy[:, 1])
    ax3.hist(one_train_npy[:, 2])
    ax4.hist(one_train_npy[:, 3])
    ax5.hist(one_train_npy[:, 4])

# %% [markdown]
# # Plot the RT for running 1 sample n times

# %%
untrained_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/one_sample_rts/untrained/"
original_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/one_sample_rts/original/"
pp_mul_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/one_sample_rts/pp_mul/"
pp_add_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/one_sample_rts/pp_add/"

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(511)
# plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
# plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
# plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
# plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
# plt.xlim(0, 0.05)

for i in range(1000):
    one_train_npy = np.load(untrained_dir + "rt_itr_" + str(i) + ".npy")
    ax1.hist(one_train_npy[:, 0])
    ax2.hist(one_train_npy[:, 1])
    ax3.hist(one_train_npy[:, 2])
    ax4.hist(one_train_npy[:, 3])
    ax5.hist(one_train_npy[:, 4])

# %%
plt.figure(figsize=(12, 12))

ax1 = plt.subplot(511)
# plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
# plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
# plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
# plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
# plt.xlim(0, 0.05)

for i in range(1000):
    one_train_npy = np.load(original_dir + "rt_itr_" + str(i) + ".npy")
    ax1.hist(one_train_npy[:, 0])
    ax2.hist(one_train_npy[:, 1])
    ax3.hist(one_train_npy[:, 2])
    ax4.hist(one_train_npy[:, 3])
    ax5.hist(one_train_npy[:, 4])

# %%
plt.figure(figsize=(12, 12))

ax1 = plt.subplot(511)
# plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
# plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
# plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
# plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
# plt.xlim(0, 0.05)

for i in range(1000):
    one_train_npy = np.load(pp_mul_dir + "rt_itr_" + str(i) + ".npy")
    ax1.hist(one_train_npy[:, 0])
    ax2.hist(one_train_npy[:, 1])
    ax3.hist(one_train_npy[:, 2])
    ax4.hist(one_train_npy[:, 3])
    ax5.hist(one_train_npy[:, 4])

# %%
plt.figure(figsize=(12, 12))

ax1 = plt.subplot(511)
# plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
# plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
# plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
# plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
# plt.xlim(0, 0.05)

for i in range(1000):
    one_train_npy = np.load(pp_add_dir + "rt_itr_" + str(i) + ".npy")
    ax1.hist(one_train_npy[:, 0])
    ax2.hist(one_train_npy[:, 1])
    ax3.hist(one_train_npy[:, 2])
    ax4.hist(one_train_npy[:, 3])
    ax5.hist(one_train_npy[:, 4])

# %% [markdown]
# # Plot the RT distribution for rand_init model and trained models

# %%
rand_rt_dir = "/Users/kiyoshi/Desktop/msdn_results/0225/rand/"

train_known_original_path = "/Users/kiyoshi/Desktop/msdn_results/0225/original/train_known_known_rts_epoch_141.npy"
train_unknown_original_path = "/Users/kiyoshi/Desktop/msdn_results/0225/original/train_known_unknown_rts_epoch_141.npy"
valid_known_original_path = "/Users/kiyoshi/Desktop/msdn_results/0225/original/valid_known_known_rts_epoch_141.npy"
valid_unknown_original_path = "/Users/kiyoshi/Desktop/msdn_results/0225/original/valid_known_unknown_rts_epoch_141.npy"

train_known_mul_path = "/Users/kiyoshi/Desktop/msdn_results/0225/pp_loss_mul/train_known_known_rts_epoch_168.npy"
train_unknown_mul_path = "/Users/kiyoshi/Desktop/msdn_results/0225/pp_loss_mul/train_known_unknown_rts_epoch_168.npy"
valid_known_mul_path = "/Users/kiyoshi/Desktop/msdn_results/0225/pp_loss_mul/valid_known_known_rts_epoch_168.npy"
valid_unknown_mul_path = "/Users/kiyoshi/Desktop/msdn_results/0225/pp_loss_mul/valid_known_unknown_rts_epoch_168.npy"

train_known_add_path = "/Users/kiyoshi/Desktop/msdn_results/0225/pp_loss_add/train_known_known_rts_epoch_111.npy"
train_unknown_add_path = "/Users/kiyoshi/Desktop/msdn_results/0225/pp_loss_add/train_known_unknown_rts_epoch_111.npy"
valid_known_add_path = "/Users/kiyoshi/Desktop/msdn_results/0225/pp_loss_add/valid_known_known_rts_epoch_111.npy"
valid_unknown_add_path = "/Users/kiyoshi/Desktop/msdn_results/0225/pp_loss_add/valid_known_unknown_rts_epoch_111.npy"

# %%
# Load the npy files for trained model
train_known_original = np.load(train_known_original_path)
train_unknown_original = np.load(train_unknown_original_path)
valid_known_original = np.load(valid_known_original_path)
valid_unknown_original = np.load(valid_unknown_original_path)

train_known_mul = np.load(train_known_mul_path)
train_unknown_mul = np.load(train_unknown_mul_path)
valid_known_mul = np.load(valid_known_mul_path)
valid_unknown_mul = np.load(valid_unknown_mul_path)

train_known_add = np.load(train_known_add_path)
train_unknown_add = np.load(train_unknown_add_path)
valid_known_add = np.load(valid_known_add_path)
valid_unknown_add = np.load(valid_unknown_add_path)

# %% [markdown]
# # Plot the histogram for trained MSD NET

# %%
# Find the max RT from all RTs
rt_max = []

rt_max.append(np.max(train_known_original))
rt_max.append(np.max(train_unknown_original))
rt_max.append(np.max(valid_known_original))
rt_max.append(np.max(valid_unknown_original))

rt_max.append(np.max(train_known_mul))
rt_max.append(np.max(train_unknown_mul))
rt_max.append(np.max(valid_known_mul))
rt_max.append(np.max(valid_unknown_mul))

rt_max.append(np.max(train_known_add))
rt_max.append(np.max(train_unknown_add))
rt_max.append(np.max(valid_known_add))
rt_max.append(np.max(valid_unknown_add))

# %%
rt_max_final = max(rt_max)
print(rt_max_final)
# Out:
# 4.7160011464729905

# %%
import math
from scipy import stats

# Basic setups
w = 0.05
w_spec = 0.0025
percentage = 0.05

bins = math.ceil((rt_max_final)/w)
bins_spec = math.ceil((rt_max_final)/w_spec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-89045f0af65a> in <module>
#       7 percentage = 0.05
#       8
# ----> 9 bins = math.ceil((rt_max_final)/w)
#      10 bins_spec = math.ceil((rt_max_final)/w_spec)
#
# NameError: name 'rt_max_final' is not defined

# %%
print(bins)
print(bins_spec)
# Out:
# 95
# 1887

# %%
plt.figure(figsize=(10, 9))

ax_1 = plt.subplot(411)
plt.xlim(0, 0.05)
ax_1.hist(train_known_original[:, 0], bins)
ax_1.hist(train_known_original[:, 1], bins)
ax_1.hist(train_known_original[:, 2], bins)
ax_1.hist(train_known_original[:, 3], bins)
ax_1.hist(train_known_original[:, 4], bins)

ax_2 = plt.subplot(412)
plt.xlim(0, 0.05)
ax_2.hist(train_unknown_original[:, 0], bins_spec)
ax_2.hist(train_unknown_original[:, 1], bins_spec)
ax_2.hist(train_unknown_original[:, 2], bins_spec)
ax_2.hist(train_unknown_original[:, 3], bins_spec)
ax_2.hist(train_unknown_original[:, 4], bins_spec)


ax_3 = plt.subplot(413)
plt.xlim(0, 0.05)
ax_3.hist(valid_known_original[:, 0], bins)
ax_3.hist(valid_known_original[:, 1], bins)
ax_3.hist(valid_known_original[:, 2], bins)
ax_3.hist(valid_known_original[:, 3], bins)
ax_3.hist(valid_known_original[:, 4], bins)

ax_4 = plt.subplot(414)
plt.xlim(0, 0.05)
ax_4.hist(valid_unknown_original[:, 0], bins)
ax_4.hist(valid_unknown_original[:, 1], bins)
ax_4.hist(valid_unknown_original[:, 2], bins)
ax_4.hist(valid_unknown_original[:, 3], bins)
ax_4.hist(valid_unknown_original[:, 4], bins)


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 9))

ax_1 = plt.subplot(411)
plt.xlim(0, 0.05)
ax_1.hist(train_known_mul[:, 0], bins)
ax_1.hist(train_known_mul[:, 1], bins)
ax_1.hist(train_known_mul[:, 2], bins)
ax_1.hist(train_known_mul[:, 3], bins)
ax_1.hist(train_known_mul[:, 4], bins)

ax_2 = plt.subplot(412)
plt.xlim(0, 0.05)
ax_2.hist(train_unknown_mul[:, 0], bins_spec)
ax_2.hist(train_unknown_mul[:, 1], bins_spec)
ax_2.hist(train_unknown_mul[:, 2], bins_spec)
ax_2.hist(train_unknown_mul[:, 3], bins_spec)
ax_2.hist(train_unknown_mul[:, 4], bins_spec)



ax_3 = plt.subplot(413)
plt.xlim(0, 0.05)
ax_3.hist(valid_known_mul[:, 0], bins)
ax_3.hist(valid_known_mul[:, 1], bins)
ax_3.hist(valid_known_mul[:, 2], bins)
ax_3.hist(valid_known_mul[:, 3], bins)
ax_3.hist(valid_known_mul[:, 4], bins)

ax_4 = plt.subplot(414)
plt.xlim(0, 0.05)
ax_4.hist(valid_unknown_mul[:, 0], bins)
ax_4.hist(valid_unknown_mul[:, 1], bins)
ax_4.hist(valid_unknown_mul[:, 2], bins)
ax_4.hist(valid_unknown_mul[:, 3], bins)
ax_4.hist(valid_unknown_mul[:, 4], bins)


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 9))

ax_1 = plt.subplot(411)
plt.xlim(0, 0.05)
ax_1.hist(train_known_add[:, 0], bins_spec)
ax_1.hist(train_known_add[:, 1], bins_spec)
ax_1.hist(train_known_add[:, 2], bins_spec)
ax_1.hist(train_known_add[:, 3], bins_spec)
ax_1.hist(train_known_add[:, 4], bins_spec)

ax_2 = plt.subplot(412)
plt.xlim(0, 0.05)
ax_2.hist(train_unknown_add[:, 0], bins_spec)
ax_2.hist(train_unknown_add[:, 1], bins_spec)
ax_2.hist(train_unknown_add[:, 2], bins_spec)
ax_2.hist(train_unknown_add[:, 3], bins_spec)
ax_2.hist(train_unknown_add[:, 4], bins_spec)



ax_3 = plt.subplot(413)
plt.xlim(0, 0.05)
ax_3.hist(valid_known_add[:, 0], bins)
ax_3.hist(valid_known_add[:, 1], bins)
ax_3.hist(valid_known_add[:, 2], bins)
ax_3.hist(valid_known_add[:, 3], bins)
ax_3.hist(valid_known_add[:, 4], bins)

ax_4 = plt.subplot(414)
plt.xlim(0, 0.05)
ax_4.hist(valid_unknown_add[:, 0], bins)
ax_4.hist(valid_unknown_add[:, 1], bins)
ax_4.hist(valid_unknown_add[:, 2], bins)
ax_4.hist(valid_unknown_add[:, 3], bins)
ax_4.hist(valid_unknown_add[:, 4], bins)


plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot the histogram for random initialized MSD-Net

# %%
nb_itr = 30

# %%
import math
from scipy import stats

# Basic setups
w = 0.005
w_spec = 0.0025
percentage = 0.05
rt_max_final = 1.0

bins = math.ceil((rt_max_final)/w)
bins_spec = math.ceil((rt_max_final)/w_spec)

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(511)
plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
plt.xlim(0, 0.05)

for i in range(nb_itr):
    one_train_npy = np.load(rand_rt_dir + "rt/known_known_rts_rand_" + str(i) + ".npy")
    #print("One known known file loaded")
    ax1.hist(one_train_npy[:, 0], bins)
    ax2.hist(one_train_npy[:, 1], bins)
    ax3.hist(one_train_npy[:, 2], bins)
    ax4.hist(one_train_npy[:, 3], bins)
    ax5.hist(one_train_npy[:, 4], bins)

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(511)
plt.xlim(0, 0.05)
ax2 = plt.subplot(512)
plt.xlim(0, 0.05)
ax3 = plt.subplot(513)
plt.xlim(0, 0.05)
ax4 = plt.subplot(514)
plt.xlim(0, 0.05)
ax5 = plt.subplot(515)
plt.xlim(0, 0.05)

for i in range(nb_itr):
    one_train_npy = np.load(rand_rt_dir + "rt/known_unknown_rts_rand_" + str(i) + ".npy")
    #print("One known known file loaded")
    ax1.hist(one_train_npy[:, 0], bins)
    ax2.hist(one_train_npy[:, 1], bins)
    ax3.hist(one_train_npy[:, 2], bins)
    ax4.hist(one_train_npy[:, 3], bins)
    ax5.hist(one_train_npy[:, 4], bins)
